# %%
# Dependencies and Setup
import pandas as pd

# Large File to Load 
Spring_2019 = "Data/Spring-2019.csv"
Summer_2019 = "Data/Summer-2019.csv"
Fall_2019 = "Data/Fall-2019.csv"
Winter_2019 = "Data/Winter-2019.csv"
# Read File and store into Pandas data frame
Spring_2019 = pd.read_csv(Spring_2019)
Summer_2019 = pd.read_csv(Summer_2019)
Fall_2019 = pd.read_csv(Fall_2019)
Winter_2019 = pd.read_csv(Winter_2019)

#Diplaying files
Spring_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1                 285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2                 686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3                 442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4                2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
# ...               ...                       ...                       ...
# 1327955           351  2019-03-31 23:59:30.5850  2019-04-01 00:05:21.7850
# 1327956          1943  2019-03-31 23:59:55.3410  2019-04-01 00:32:18.6920
# 1327957           515  2019-03-31 23:59:50.1810  2019-04-01 00:08:25.8330
# 1327958           660  2019-03-31 23:59:56.6520  2019-04-01 00:10:57.3760
# 1327959           132  2019-03-31 23:59:58.0230  2019-04-01 00:02:10.5920
#
#          start station id        start station name  start station latitude  \
# ...

# %%
Summer_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 139  2019-05-01 00:00:01.9010  2019-05-01 00:02:21.5170
# 1                 754  2019-05-01 00:00:03.0210  2019-05-01 00:12:37.6920
# 2                2308  2019-05-01 00:00:04.6270  2019-05-01 00:38:33.1710
# 3                 143  2019-05-01 00:00:19.3340  2019-05-01 00:02:42.5200
# 4                 138  2019-05-01 00:00:22.1840  2019-05-01 00:02:40.6480
# ...               ...                       ...                       ...
# 1924558           304  2019-05-31 23:59:45.5760  2019-06-01 00:04:50.4620
# 1924559           324  2019-05-31 23:59:46.4650  2019-06-01 00:05:11.1630
# 1924560          1926  2019-05-31 23:59:51.5060  2019-06-01 00:31:58.3920
# 1924561          2047  2019-05-31 23:59:52.4170  2019-06-01 00:34:00.1970
# 1924562           964  2019-05-31 23:59:55.5500  2019-06-01 00:15:59.8680
#
#          start station id         start station name  start station latitude  \
# ...

# %%
Fall_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1                 627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2                1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3                1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4                1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# ...               ...                       ...                       ...
# 2344219           216  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 2344220           117  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 2344221          1614  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 2344222          1301  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 2344223           419  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id              start station name  \
# ...

# %%
Winter_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 273  2019-11-01 00:00:00.2930  2019-11-01 00:04:34.1880
# 1                 159  2019-11-01 00:00:03.5840  2019-11-01 00:02:43.4780
# 2                 967  2019-11-01 00:00:06.2670  2019-11-01 00:16:14.0990
# 3                 604  2019-11-01 00:00:21.7610  2019-11-01 00:10:25.8910
# 4                 153  2019-11-01 00:00:25.2060  2019-11-01 00:02:59.0180
# ...               ...                       ...                       ...
# 1478703           534  2019-11-30 23:59:07.8070  2019-12-01 00:08:01.9840
# 1478704           269  2019-11-30 23:59:14.4120  2019-12-01 00:03:43.6630
# 1478705           668  2019-11-30 23:59:26.4970  2019-12-01 00:10:35.2200
# 1478706           450  2019-11-30 23:59:28.5170  2019-12-01 00:06:58.7670
# 1478707           811  2019-11-30 23:59:50.4100  2019-12-01 00:13:22.3840
#
#          start station id                  start station name  \
# ...

# %%
#Droping duplicates i don't care about the extra rides that bike took

Spring = Spring_2019.drop_duplicates("bikeid")
Summer = Summer_2019.drop_duplicates("bikeid")
Fall = Fall_2019.drop_duplicates("bikeid")
Winter = Winter_2019.drop_duplicates("bikeid")


Spring
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1                 285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2                 686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3                 442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4                2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
# ...               ...                       ...                       ...
# 1278213          1230  2019-03-30 17:29:38.5320  2019-03-30 17:50:09.3160
# 1280877           970  2019-03-30 18:00:10.3850  2019-03-30 18:16:20.8480
# 1299465           580  2019-03-31 09:01:04.2340  2019-03-31 09:10:44.6800
# 1317693           519  2019-03-31 17:37:10.8510  2019-03-31 17:45:50.6870
# 1320830           899  2019-03-31 18:36:53.3170  2019-03-31 18:51:52.4270
#
#          start station id            start station name  \
# ...

# %%
Summer
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 139  2019-05-01 00:00:01.9010  2019-05-01 00:02:21.5170
# 1                 754  2019-05-01 00:00:03.0210  2019-05-01 00:12:37.6920
# 2                2308  2019-05-01 00:00:04.6270  2019-05-01 00:38:33.1710
# 3                 143  2019-05-01 00:00:19.3340  2019-05-01 00:02:42.5200
# 4                 138  2019-05-01 00:00:22.1840  2019-05-01 00:02:40.6480
# ...               ...                       ...                       ...
# 1902246          1327  2019-05-31 18:16:49.8440  2019-05-31 18:38:57.7390
# 1920192           814  2019-05-31 22:00:03.6880  2019-05-31 22:13:38.2310
# 1920447          1489  2019-05-31 22:06:24.6680  2019-05-31 22:31:14.5560
# 1924195           335  2019-05-31 23:48:30.2020  2019-05-31 23:54:06.1520
# 1924489         63985  2019-05-31 23:57:11.8830  2019-06-01 17:43:37.6540
#
#          start station id                 start station name  \
# ...

# %%
Fall
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1                 627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2                1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3                1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4                1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# ...               ...                       ...                       ...
# 2335344          2411  2019-08-31 19:41:57.6080  2019-08-31 20:22:09.4510
# 2335784          1044  2019-08-31 19:49:27.5650  2019-08-31 20:06:52.1760
# 2339371           548  2019-08-31 21:09:30.7650  2019-08-31 21:18:39.7040
# 2341930          1042  2019-08-31 22:28:49.8070  2019-08-31 22:46:12.7340
# 2343809          1576  2019-08-31 23:40:55.3420  2019-09-01 00:07:12.2010
#
#          start station id              start station name  \
# ...

# %%
Winter
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 273  2019-11-01 00:00:00.2930  2019-11-01 00:04:34.1880
# 1                 159  2019-11-01 00:00:03.5840  2019-11-01 00:02:43.4780
# 2                 967  2019-11-01 00:00:06.2670  2019-11-01 00:16:14.0990
# 3                 604  2019-11-01 00:00:21.7610  2019-11-01 00:10:25.8910
# 4                 153  2019-11-01 00:00:25.2060  2019-11-01 00:02:59.0180
# ...               ...                       ...                       ...
# 1456825           573  2019-11-30 10:46:32.2980  2019-11-30 10:56:06.2470
# 1459296           686  2019-11-30 12:02:42.1590  2019-11-30 12:14:08.6180
# 1464198          1085  2019-11-30 14:12:41.2280  2019-11-30 14:30:46.4630
# 1466249          1045  2019-11-30 15:02:42.1560  2019-11-30 15:20:07.3110
# 1476030           506  2019-11-30 20:31:36.5990  2019-11-30 20:40:03.1720
#
#          start station id            start station name  \
# ...

# %%
Spring.to_csv("Data/Spring.csv", index=False, header=True)
Summer.to_csv("Data/Summer.csv", index=False, header=True)
Fall.to_csv("Data/Fall.csv", index=False, header=True)
Winter.to_csv("Data/Winter.csv", index=False, header=True)
